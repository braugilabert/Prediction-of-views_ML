# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/raw/dataset siralatriste.csv')
data.head(1)
# Out:
#                                     Título del vídeo  Visualizaciones  \
# 0  El ejército que nunca se rendía - El último te...            47210
#
#               Juego   SEO  Compartido  Tiempo de visualización (horas)  \
# 0  Empire Total War  57.0          67                        1580.8846
#
#    Suscriptores  Impresiones  Me gusta (vs. No me gusta) (%)  Me gusta  \
# 0            25        62129                           87.19       279
#
#    Duración media de las visualizaciones  \
# 0                                    2.0
#
#   Datos Duración media de las visualizaciones  Comentarios  \
# 0                                     0:02:00           39
#
#    Porcentaje de clics de las impresiones (%)        Fecha
# 0                                        8.69  Mar 2, 2015

# %%
sns.pairplot(data);

# %%
siralatriste_target = data["Visualizaciones"]
sns.kdeplot(siralatriste_target);

# %%
plt.figure(figsize=(15,15))
sns.violinplot(x="Juego", y="Visualizaciones", data=data);

# %%
data.corr()
# Out:
# C:\Users\Braulio\AppData\Local\Temp\ipykernel_4680\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                             Visualizaciones       SEO  \
# Visualizaciones                                    1.000000  0.022918
# SEO                                                0.022918  1.000000
# Compartido                                         0.840250  0.068535
# Tiempo de visualización (horas)                    0.818473  0.104328
# Suscriptores                                       0.539642  0.067234
# Impresiones                                        0.813631  0.081196
# Me gusta (vs. No me gusta) (%)                     0.024723  0.034698
# Me gusta                                           0.212741  0.005231
# ...
